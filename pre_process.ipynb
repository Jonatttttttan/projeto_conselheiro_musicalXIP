# %%
import pandas as pd
import os
import shutil

# %%
CAMINHO = "C:\\Users\\Nitro\\Desktop\\Python_IA_projetos\\Databases\\Taylor_Swift\\data\\Albums"

# %% [markdown]
# # Visualizando dados

# %%
folders = os.listdir(CAMINHO)
folders = [CAMINHO + "\\" + x for x in folders]

# criando pasta comum
def mover(folders):
    import shutil
    CAMINHO_PASTA_COMUM = "C:\\Users\\Nitro\\Desktop\\Python_IA_projetos\\Projeto_Conselheiro_Musical\\db_musics"
    files = [[x + "\\" + u for u in os.listdir(x)] for x in folders]

    files = [u for x in files for u in x]


    for file in files:
        shutil.copy(file, CAMINHO_PASTA_COMUM)


    return

mover(folders)
